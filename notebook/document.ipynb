# %% [markdown]
# ### Data Ingestion

# %%
### Document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the main text content, I am using to create RAG.",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Dayachand",
        "date_created":"2026-01-01"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Dayachand', 'date_created': '2026-01-01'}, page_content='This is the main text content, I am using to create RAG.')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt": """
Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
It is widely used in web development, data science, machine learning, automation, and artificial intelligence.

Key Features of Python:
1. Easy-to-read syntax.
2. Large standard library.
3. Cross-platform compatibility.
4. Extensive community support.
5. Supports object-oriented programming.

Example:
print("Hello, World!")

Python was created by Guido van Rossum and released in 1991.
""",

    "../data/text_files/machine_learning.txt": """
Introduction to Machine Learning

Machine Learning is a branch of Artificial Intelligence that enables computers to learn patterns from data
without being explicitly programmed.

Types of Machine Learning:
1. Supervised Learning
2. Unsupervised Learning
3. Reinforcement Learning

Common Algorithms:
- Linear Regression
- Logistic Regression
- Decision Trees
- Random Forest
- K-Means Clustering

Applications include recommendation systems, image recognition, spam detection, and predictive analytics.
"""
}

for filepath,content in sample_texts.items():
    with open(filepath,"w",encoding="utf-8") as f:
        f.write(content)

print("Sample text file Created.")
# Out:
# Sample text file Created.

# %%
### TextLoader
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='\nPython Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nIt is widely used in web development, data science, machine learning, automation, and artificial intelligence.\n\nKey Features of Python:\n1. Easy-to-read syntax.\n2. Large standard library.\n3. Cross-platform compatibility.\n4. Extensive community support.\n5. Supports object-oriented programming.\n\nExample:\nprint("Hello, World!")\n\nPython was created by Guido van Rossum and released in 1991.\n')]

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\DAYACHAND\Desktop\RAG\.venv\Scripts\python.exe

# %%
# %pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\dayachand\desktop\rag\.venv\lib\site-packages (4.67.3)
# Requirement already satisfied: colorama in c:\users\dayachand\desktop\rag\.venv\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader
from tqdm import tqdm

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=True
)

documents = dir_loader.load()
documents
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 491.45it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='\nIntroduction to Machine Learning\n\nMachine Learning is a branch of Artificial Intelligence that enables computers to learn patterns from data\nwithout being explicitly programmed.\n\nTypes of Machine Learning:\n1. Supervised Learning\n2. Unsupervised Learning\n3. Reinforcement Learning\n\nCommon Algorithms:\n- Linear Regression\n- Logistic Regression\n- Decision Trees\n- Random Forest\n- K-Means Clustering\n\nApplications include recommendation systems, image recognition, spam detection, and predictive analytics.\n'),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='\nPython Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nIt is widely used in web development, data science, machine learning, automation, and artificial intelligence.\n\nKey Features of Python:\n1. Easy-to-read syntax.\n2. Large standard library.\n3. Cross-platform compatibility.\n4. Extensive community support.\n5. Supports object-oriented programming.\n\nExample:\nprint("Hello, World!")\n\nPython was created by Guido van Rossum and released in 1991.\n')]

# %%
### Pdf Loader
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader, DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=True
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# 100%|██████████| 4/4 [00:03<00:00,  1.03it/s]
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 0}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 1\nLeetCode Patterns\nComplete Study Guide\n27 Core Patterns · 160+ Problems · DSA Mastery Roadmap\n27\n160+\n6\nEasy→Hard\nPatterns\nProblems\nDifficulty\nLevels\nProgression\nArrays &\nStrings\nLinked Lists\nTrees &\nGraphs\nDynamic\nProgramming\nGreedy &\nSorting\nAdvanced DS'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 1}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 2\nTable of Contents\n#\nPattern\nProblems\nDifficulty\n1\nSliding Window\n3, 76, 209, 424, 567, 904\nEasy→Hard\n2\nTwo Pointers\n11, 15, 16, 18, 42, 167\nEasy→Hard\n3\nFast/Slow Pointers\n141, 142, 19, 876, 160, 234\nEasy→Medium\n4\nBinary Search on Sorted Data\n33, 34, 35, 153, 162, 704\nEasy→Medium\n5\nBinary Search on Answer\n875, 1011, 410, 774, 1283, 1482\nMedium→Hard\n6\nHashing / Frequency Maps\n1, 49, 128, 217, 242, 347\nEasy→Medium\n7\nPrefix Sum / Running Sum\n303, 560, 724, 930, 974, 523\nEasy→Medium\n8\nDifference Array / Range Updates\n370, 1094, 1109, 1893, 1943, 2381\nMedium\n9\nMonotonic Stack\n739, 496, 503, 84, 85, 901\nMedium→Hard\n10\nMonotonic Queue / Deque\n239, 862, 1425, 1438, 1499, 1696\nHard\n11\nHeap / Top K\n215, 347, 692, 703, 973, 1046\nMedium\n12\nIntervals\n56, 57, 252, 253, 435, 452\nEasy→Hard\n13\nGreedy Scheduling / Sorting\n45, 55, 406, 621, 763, 134\nMedium→Hard\n14\nLinked List Manipulation\n21, 23, 24, 25, 92, 138\nEasy→Hard\n15\nTree DFS\n104, 112, 113, 543, 124, 226\nEasy→Hard\n16\nTree BFS / Level Order\n102, 103, 199, 515, 637, 116\nEasy→Medium\n17\nBST Problems\n98, 99, 230, 235, 450, 700\nEasy→Hard\n18\nBacktracking Basics\n46, 47, 77, 78, 90, 39\nMedium\n19\nBacktracking with Constraints\n40, 17, 79, 131, 51, 52\nMedium→Hard\n20\nGraph BFS / DFS\n200, 695, 733, 994, 1091, 1254\nEasy→Medium\n21\nTopological Sort / DAG\n207, 210, 802, 1462, 1203, 2115\nMedium→Hard\n22\nUnion Find / DSU\n547, 684, 1319, 1579, 990, 1202\nMedium→Hard\n23\nShortest Path\n743, 787, 1514, 1631, 1334, 1976\nMedium→Hard\n24\nMST / Graph Greedy\n1584, 1135, 1168, 1489, 778, 1102\nHard\n25\nTrie\n208, 211, 212, 648, 677, 1268\nMedium→Hard\n26\nBit Manipulation\n136, 137, 191, 338, 268, 190\nEasy→Medium\n27\n1D DP Basics\n70, 198, 213, 322, 279, 300\nEasy→Medium'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 2}, page_content="LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 3\nPattern Reference Cards\n1\nSliding Window\nDifficulty: Easy→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nMaintain a window over a contiguous\nsubarray/substring. Expand right, shrink left when\nconstraint violated. O(n) time.\n• Fixed-size window\n• Variable-size window\n• Character frequency tracking\nLEETCODE PROBLEMS\n#3\n#76\n#209\n#424\n#567\n#904\n2\nTwo Pointers\nDifficulty: Easy→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nUse two indices moving toward each other or in\nthe same direction to reduce O(n²) brute force to\nO(n).\n• Opposite ends (sorted array)\n• Same direction (partitioning)\n• Container / area problems\nLEETCODE PROBLEMS\n#11\n#15\n#16\n#18\n#42\n#167\n3\nFast/Slow Pointers\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nTwo pointers at different speeds to detect cycles\nor find midpoints in linked lists. Floyd's cycle\ndetection.\n• Cycle detection\n• Cycle entry point\n• Middle of list\n• Intersection\nLEETCODE PROBLEMS\n#141\n#142\n#19\n#876\n#160\n#234"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 3}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 4\n4\nBinary Search on Sorted Data\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nEliminate half the search space each iteration on\nsorted or rotated sorted arrays. O(log n) time.\n• Classic search\n• Leftmost/rightmost position\n• Rotated sorted array\n• Peak finding\nLEETCODE PROBLEMS\n#33\n#34\n#35\n#153\n#162\n#704\n5\nBinary Search on Answer\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nWhen the answer lives in a monotonic range,\nbinary search on the answer space and use a\nfeasibility check.\n• Minimize maximum\n• Maximize minimum\n• Capacity / allocation problems\nLEETCODE PROBLEMS\n#875\n#1011\n#410\n#774\n#1283\n#1482\n6\nHashing / Frequency Maps\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nUse hash maps/sets for O(1) lookup, grouping,\ncounting, or de-duplication. Trade space for time.\n• Two-sum lookup\n• Anagram grouping\n• Longest consecutive sequence\n• Top-K frequency\nLEETCODE PROBLEMS\n#1\n#49\n#128\n#217\n#242\n#347'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 4}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 5\n7\nPrefix Sum / Running Sum\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nPrecompute cumulative sums so any subarray\nsum is O(1). Combine with hash maps for\nsubarray sum targets.\n• Range sum query\n• Subarray sum equals K\n• Pivot index\n• Divisible subarray\nLEETCODE PROBLEMS\n#303\n#560\n#724\n#930\n#974\n#523\n8\nDifference Array / Range Updates\nDifficulty: Medium\nCONCEPT\nSUBTYPES / USE-CASES\nApply range increment/decrement in O(1) using a\ndifference array, then reconstruct with prefix sum.\n• Range add queries\n• Interval coverage\n• Flower planting\n• Car pooling\nLEETCODE PROBLEMS\n#370\n#1094\n#1109\n#1893\n#1943\n#2381\n9\nMonotonic Stack\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nMaintain a stack in strictly increasing or\ndecreasing order to answer next-greater/smaller\nin O(n) amortized.\n• Next greater element\n• Largest rectangle in histogram\n• Stock span\n• Maximal rectangle\nLEETCODE PROBLEMS\n#739\n#496\n#503\n#84\n#85\n#901'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 5}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 6\n10\nMonotonic Queue / Deque\nDifficulty: Hard\nCONCEPT\nSUBTYPES / USE-CASES\nDeque-based window max/min in O(n). Front\nholds the optimal element; expired elements are\npopped from front.\n• Sliding window maximum\n• Constrained subsequence sum\n• Jump game with deque\nLEETCODE PROBLEMS\n#239\n#862\n#1425\n#1438\n#1499\n#1696\n11\nHeap / Top K\nDifficulty: Medium\nCONCEPT\nSUBTYPES / USE-CASES\nUse a min-heap of size K for Top-K elements in\nO(n log K). Max-heap for kth-smallest variants.\n• Kth largest element\n• Top K frequent\n• K closest points\n• Last stone weight\nLEETCODE PROBLEMS\n#215\n#347\n#692\n#703\n#973\n#1046\n12\nIntervals\nDifficulty: Easy→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nSort by start time. Merge overlapping intervals,\ncount rooms needed, or find minimum arrows.\n• Merge intervals\n• Insert interval\n• Meeting rooms\n• Non-overlapping intervals\nLEETCODE PROBLEMS\n#56\n#57\n#252\n#253\n#435\n#452'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 6}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 7\n13\nGreedy Scheduling / Sorting\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nMake locally optimal choices. Often requires a\nclever sort key or greedy observation about the\noptimal structure.\n• Jump game\n• Task scheduler\n• Queue reconstruction\n• Partition labels\nLEETCODE PROBLEMS\n#45\n#55\n#406\n#621\n#763\n#134\n14\nLinked List Manipulation\nDifficulty: Easy→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nIn-place pointer rewiring. Use dummy head\nnodes, prev/curr pointers, and careful order of\nassignments.\n• Merge sorted lists\n• Reverse sublist\n• Swap in pairs\n• Deep copy with random\nLEETCODE PROBLEMS\n#21\n#23\n#24\n#25\n#92\n#138\n15\nTree DFS\nDifficulty: Easy→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nRecursive or iterative pre/in/post-order traversal.\nPass state top-down; aggregate results\nbottom-up.\n• Max depth\n• Path sum\n• Diameter\n• Max path sum\n• Mirror tree\nLEETCODE PROBLEMS\n#104\n#112\n#113\n#543\n#124\n#226'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 7}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 8\n16\nTree BFS / Level Order\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nUse a queue to process nodes level by level.\nTrack level boundaries with size snapshotting.\n• Level order traversal\n• Zigzag\n• Right side view\n• Average of levels\nLEETCODE PROBLEMS\n#102\n#103\n#199\n#515\n#637\n#116\n17\nBST Problems\nDifficulty: Easy→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nLeverage BST invariant (left < root < right).\nIn-order traversal yields sorted order.\n• Validate BST\n• Recover BST\n• Kth smallest\n• LCA\n• Delete node\n• Search\nLEETCODE PROBLEMS\n#98\n#99\n#230\n#235\n#450\n#700\n18\nBacktracking Basics\nDifficulty: Medium\nCONCEPT\nSUBTYPES / USE-CASES\nExplore all combinations/permutations via DFS +\nundo. Prune early to cut branches.\n• Permutations\n• Combinations\n• Subsets\n• Combination sum\nLEETCODE PROBLEMS\n#46\n#47\n#77\n#78\n#90\n#39'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 8}, page_content="LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 9\n19\nBacktracking with Constraints\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nBacktracking with tighter pruning: used-element\ntracking, board constraints, or partition rules.\n• Combination sum II\n• Phone letters\n• Word search\n• N-Queens\n• Palindrome partitioning\nLEETCODE PROBLEMS\n#40\n#17\n#79\n#131\n#51\n#52\n20\nGraph BFS / DFS\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nTraverse grids or adjacency lists. BFS for\nshortest path; DFS for connected components.\n• Number of islands\n• Flood fill\n• Rotting oranges\n• Shortest path in binary matrix\nLEETCODE PROBLEMS\n#200\n#695\n#733\n#994\n#1091\n#1254\n21\nTopological Sort / DAG\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nKahn's algorithm (BFS in-degree) or DFS\npost-order to linearize a DAG. Detect cycles\nsimultaneously.\n• Course schedule\n• Find eventual safe states\n• Sort items by groups\nLEETCODE PROBLEMS\n#207\n#210\n#802\n#1462\n#1203\n#2115"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 9}, page_content="LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 10\n22\nUnion Find / DSU\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nDisjoint Set Union with path compression + union\nby rank. Near-O(1) amortized find/union.\n• Number of provinces\n• Redundant connection\n• Smallest string with swaps\nLEETCODE PROBLEMS\n#547\n#684\n#1319\n#1579\n#990\n#1202\n23\nShortest Path\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nDijkstra (non-negative weights), Bellman-Ford\n(negative edges), BFS (unit weights), or modified\nvariants.\n• Dijkstra\n• Cheapest flights (K stops)\n• Path with max probability\n• Swim in rising water\nLEETCODE PROBLEMS\n#743\n#787\n#1514\n#1631\n#1334\n#1976\n24\nMST / Graph Greedy\nDifficulty: Hard\nCONCEPT\nSUBTYPES / USE-CASES\nKruskal's (sort edges + DSU) or Prim's (priority\nqueue) for minimum spanning tree.\n• Min cost to connect points\n• Optimize water distribution\n• Swim in rising water\nLEETCODE PROBLEMS\n#1584\n#1135\n#1168\n#1489\n#778\n#1102"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-26T00:03:41+00:00', 'source': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'file_path': '..\\data\\pdf\\LeetCode_Patterns_Guide2.pdf', 'total_pages': 11, 'format': 'PDF 1.4', 'title': 'LeetCode Patterns — Complete Study Guide', 'author': 'Generated Study Guide', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-26T00:03:41+00:00', 'trapped': '', 'modDate': "D:20260526000341+00'00'", 'creationDate': "D:20260526000341+00'00'", 'page': 10}, page_content='LeetCode Patterns — Complete Study Guide\n27 Core Patterns\nPage 11\n25\nTrie\nDifficulty: Medium→Hard\nCONCEPT\nSUBTYPES / USE-CASES\nPrefix tree for O(L) insert/search where L = word\nlength. Enables prefix queries and autocomplete.\n• Implement trie\n• Word search II\n• Replace words\n• Map sum pairs\nLEETCODE PROBLEMS\n#208\n#211\n#212\n#648\n#677\n#1268\n26\nBit Manipulation\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nXOR, AND, OR, shifts to solve problems in O(1)\nspace. XOR cancels duplicates; bit counting via\nkernighan.\n• Single number\n• Missing number\n• Counting bits\n• Reverse bits\nLEETCODE PROBLEMS\n#136\n#137\n#191\n#338\n#268\n#190\n27\n1D DP Basics\nDifficulty: Easy→Medium\nCONCEPT\nSUBTYPES / USE-CASES\nBuild solutions from smaller subproblems. Define\nstate, recurrence, and base cases clearly.\n• Climbing stairs\n• House robber\n• Coin change\n• Perfect squares\n• LIS\nLEETCODE PROBLEMS\n#70\n#198\n#213\n#322\n#279\n#300'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 1}, page_content='Installing MySQL\nWhat is MySQL workbench?\nMySQL Workbench is a visual tool for database architects, developers, and DBAs. It\nprovides data modeling, SQL development, and comprehensive administration\ntools for server configuration, user administration, backup, and much more.\nWhat is a Database Management System (DBMS)?\nA Database Management System (DBMS) is software that interacts with end users,\napplications, and the database itself to capture and analyze data. It allows for the\ncreation, retrieval, updating, and management of data in databases. If you know\none DBMS, you can easily transition to another, as they share similar concepts and\nfunctionalities.\nWindows / macOS Installation\nDownload from: https://dev.mysql.com/downloads/installer/\nRun the installer and choose Developer Default.\nSet a root password when prompted.\nInstall MySQL Workbench (optional but helpful GUI).\nLinux (Ubuntu) Installation\nFollow these steps to install MySQL and create a user:\n1. \n2. \n3. \n4.'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 2}, page_content="Step 1: Update Package Index\nStep 2: Install MySQL Server\nStep 3: Secure the Installation\nChoose your options (yes to most).\nStep 4: Create a User 'harry'@'localhost'\nLog into MySQL:\nRun the following SQL commands:\nsudo apt update\nsudo apt install mysql-server\nsudo mysql_secure_installation\nsudo mysql\nCREATE USER 'harry'@'localhost' IDENTIFIED BY 'password';\nGRANT ALL PRIVILEGES ON *.* TO 'harry'@'localhost' WITH GRANT OPTION;\nFLUSH PRIVILEGES;\nEXIT;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 3}, page_content="Step 5: Test Login\nEnter the password: password\nMake sure to replace 'password'  with a secure password of your choice in\nproduction environments.\nmysql -u harry -p"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 4}, page_content='Getting Started with MySQL\nWhat is a Database?\nA database is a container that stores related data in an organized way. In MySQL, a\ndatabase holds one or more tables.\nThink of it like:\nFolder analogy:\nA database is like a folder.\nEach table is a file inside that folder.\nThe rows in the table are like the content inside each file.\nExcel analogy:\nA database is like an Excel workbook.\nEach table is a separate sheet inside that workbook.\nEach row in the table is like a row in Excel.\nStep 1: Create a Database\nAfter creating the database, either:\nRight-click it in MySQL Workbench and select “Set as Default Schema”, or\nUse this SQL command:\n• \n• \n• \n• \n• \n• \n• \n• \nCREATE DATABASE startersql;\n• \n• \nUSE startersql;'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 5}, page_content="Step 2: Create a Table\nNow we’ll create a simple users  table:\nThis table will store basic user info.\nStep 3: Drop the Database\nYou can delete the entire database (and all its tables) using:\nBe careful — this will delete everything in that database.\nData Types Explained\nINT : Integer type, used for whole numbers.\nVARCHAR(100) : Variable-length string, up to 100 characters.\nENUM : A string object with a value chosen from a list of permitted values. eg. \ngender ENUM('Male', 'Female', 'Other')\nDATE : Stores date values. eg date_of_birth DATE\nCREATE TABLE users (\nid INT AUTO_INCREMENT PRIMARY KEY,\n    name VARCHAR(100) NOT NULL,\n    email VARCHAR(100) UNIQUE NOT NULL,\n    gender ENUM('Male', 'Female', 'Other'),\n    date_of_birth DATE,\n    created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP\n);\nDROP DATABASE startersql;\n• \n• \n• \n•"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 6}, page_content='TIMESTAMP : Stores date and time, automatically set to the current timestamp\nwhen a row is created.\nBOOLEAN : Stores TRUE or FALSE values, often used for flags like is_active .\nDECIMAL(10, 2) : Stores exact numeric data\nvalues, useful for financial data. The first number is\nthe total number of digits, and the second is the\nnumber of digits after the decimal point.\nConstraints Explained\nAUTO_INCREMENT : Automatically generates a unique number for each row.\nPRIMARY KEY : Uniquely identifies each row in the table.\nNOT NULL : Ensures a column cannot have a NULL value.\nUNIQUE : Ensures all values in a column are different.\nDEFAULT : Sets a default value for a column if no value is provided. eg. \ncreated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP , is_active BOOLEAN \nDEFAULT TRUE\n• \n• \n• \n• \n• \n• \n• \n•'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 7}, page_content='Working with Tables in MySQL\nSelecting Data from a Table\nSelect All Columns\nThis fetches every column and every row from the users  table.\nSelect Specific Columns\nThis only fetches the name  and email  columns from all rows.\nRenaming a Table\nTo rename an existing table:\nTo rename it back:\nSELECT * FROM users;\nSELECT name, email FROM users;\nRENAME TABLE users TO customers;\nRENAME TABLE customers TO users;'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 8}, page_content="Altering a Table\nYou can use ALTER TABLE  to modify an existing table.\nAdd a Column\nDrop a Column\nModify a Column Type\nMove a Column to the First Position\nTo move a column (e.g., email ) to the first position:\nTo move a column after another column (e.g., move gender  after name ):\nALTER TABLE users ADD COLUMN is_active BOOLEAN DEFAULT TRUE;\nALTER TABLE users DROP COLUMN is_active;\nALTER TABLE users MODIFY COLUMN name VARCHAR(150);\nALTER TABLE users MODIFY COLUMN email VARCHAR(100) FIRST;\nALTER TABLE users MODIFY COLUMN gender ENUM('Male', 'Female', 'Other') AFTER name;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 9}, page_content="Inserting Data into MySQL Tables\nTo add data into a table, we use the INSERT INTO  statement.\nInsert Without Specifying Column Names (Full Row\nInsert)\nThis method requires you to provide values for all columns in order, except\ncolumns with default values or AUTO_INCREMENT .\nNot recommended if your table structure might change (e.g., new columns\nadded later).\nInsert by Specifying Column Names (Best Practice)\nThis method is safer and more readable. You only insert into specific columns.\nor for multiple rows:\nINSERT INTO users VALUES\n(1, 'Alice', 'alice@example.com', 'Female', '1995-05-14', DEFAULT);\nINSERT INTO users (name, email, gender, date_of_birth) VALUES\n('Bob', 'bob@example.com', 'Male', '1990-11-23');\nINSERT INTO users (name, email, gender, date_of_birth) VALUES\n('Bob', 'bob@example.com', 'Male', '1990-11-23'),\n('Charlie', 'charlie@example.com', 'Other', '1988-02-17');"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 10}, page_content="The remaining columns like id  (which is AUTO_INCREMENT ) and created_at\n(which has a default) are automatically handled by MySQL.\nInsert Multiple Rows at Once\nThis is more efficient than inserting rows one by one.\nINSERT INTO users (name, email, gender, date_of_birth) VALUES\n('Charlie', 'charlie@example.com', 'Other', '1988-02-17'),\n('David', 'david@example.com', 'Male', '2000-08-09'),\n('Eva', 'eva@example.com', 'Female', '1993-12-30');"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 11}, page_content="Querying Data in MySQL using SELECT\nThe SELECT  statement is used to query data from a table.\nBasic Syntax\nTo select all columns:\nFiltering Rows with WHERE\nEqual To\nNot Equal To\nSELECT column1, column2 FROM table_name;\nSELECT * FROM users;\nSELECT * FROM users WHERE gender = 'Male';\nSELECT * FROM users WHERE gender != 'Female';\n-- or\nSELECT * FROM users WHERE gender <> 'Female';"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 12}, page_content="Greater Than / Less Than\nGreater Than or Equal / Less Than or Equal\nWorking with NULL\nIS NULL\nIS NOT NULL\nBETWEEN\nSELECT * FROM users WHERE date_of_birth < '1995-01-01';\nSELECT * FROM users WHERE id > 10;\nSELECT * FROM users WHERE id >= 5;\nSELECT * FROM users WHERE id <= 20;\nSELECT * FROM users WHERE date_of_birth IS NULL;\nSELECT * FROM users WHERE date_of_birth IS NOT NULL;\nSELECT * FROM users WHERE date_of_birth BETWEEN '1990-01-01' AND '2000-12-31';"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 13}, page_content="IN\nLIKE (Pattern Matching)\nAND / OR\nORDER BY\nLIMIT\nSELECT * FROM users WHERE gender IN ('Male', 'Other');\nSELECT * FROM users WHERE name LIKE 'A%';\n-- Starts with A\nSELECT * FROM users WHERE name LIKE '%a';\n-- Ends with a\nSELECT * FROM users WHERE name LIKE '%li%'; -- Contains 'li'\nSELECT * FROM users WHERE gender = 'Female' AND date_of_birth > '1990-01-01';\nSELECT * FROM users WHERE gender = 'Male' OR gender = 'Other';\nSELECT * FROM users ORDER BY date_of_birth ASC;\nSELECT * FROM users ORDER BY name DESC;\nSELECT * FROM users LIMIT 5;\n-- Top 5 rows\nSELECT * FROM users LIMIT 10 OFFSET 5;\n-- Skip first 5 rows, then get next 10\nSELECT * FROM users LIMIT 5, 10;\n-- Get 10 rows starting from the 6th row (Same as"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 14}, page_content='Quick Quiz\nWhat does the following queries do?\nabove)\nSELECT * FROM users ORDER BY created_at DESC LIMIT 10;\nSELECT * FROM users WHERE salary > 60000 ORDER BY created_at DESC LIMIT 5;\nSELECT * FROM users ORDER BY salary DESC;\nSELECT * FROM users WHERE salary BETWEEN 50000 AND 70000;'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 15}, page_content="UPDATE - Modifying Existing Data\nThe UPDATE  statement is used to change values in one or more rows.\nBasic Syntax\nExample: Update One Column\nThis changes the name of the user with id = 1  to “Alicia”.\nExample: Update Multiple Columns\nWithout WHERE Clause (Warning)\nUPDATE table_name\nSET column1 = value1, column2 = value2\nWHERE condition;\nUPDATE users\nSET name = 'Alicia'\nWHERE id = 1;\nUPDATE users\nSET name = 'Robert', email = 'robert@example.com'\nWHERE id = 2;\nUPDATE users\nSET gender = 'Other';"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 16}, page_content="This updates every row in the table. Be very careful when omitting the WHERE\nclause.\nQuick Quiz: Practice Your UPDATE  Skills\nTry answering or running these queries based on your users  table.\n1. Update the salary of user with id = 5  to ₹70,000.\n2. Change the name of the user with email aisha@example.com\nto Aisha Khan .\n3. Increase salary by ₹10,000 for all users whose salary is less\nthan ₹60,000.\nUPDATE users\nSET salary = 70000\nWHERE id = 5;\nUPDATE users\nSET name = 'Aisha Khan'\nWHERE email = 'aisha@example.com';\nUPDATE users\nSET salary = salary + 10000\nWHERE salary < 60000;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 17}, page_content="4. Set the gender of user Ishaan  to Other .\n5. Reset salary of all users to ₹50,000 (Careful - affects all rows).\nNote: This query will overwrite salary for every user. Use with caution!\nUPDATE users\nSET gender = 'Other'\nWHERE name = 'Ishaan';\nUPDATE users\nSET salary = 50000;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 18}, page_content="DELETE - Removing Data from a Table\nThe DELETE  statement removes rows from a table.\nBasic Syntax\nExample: Delete One Row\nDelete Multiple Rows\nDelete All Rows (but keep table structure)\nDrop the Entire Table (use with caution)\nDELETE FROM table_name\nWHERE condition;\nDELETE FROM users\nWHERE id = 3;\nDELETE FROM users\nWHERE gender = 'Other';\nDELETE FROM users;\nDROP TABLE users;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 19}, page_content='This removes the table structure and all data permanently.\nBest Practices\nAlways use WHERE  unless you’re intentionally updating/deleting everything.\nConsider running a SELECT  with the same WHERE  clause first to confirm what\nwill be affected:\nAlways back up important data before performing destructive operations.\nQuick Quiz: Practice Your DELETE  Skills\nwhat will happen if you run these queries?\n• \n• \nSELECT * FROM users WHERE id = 3;\n• \nDELETE FROM users\nWHERE salary < 50000;\nDELETE FROM users\nWHERE salary IS NULL;'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 20}, page_content='MySQL Constraints\nConstraints in MySQL are rules applied to table columns to ensure the accuracy, \nvalidity, and integrity of the data.\n1. UNIQUE  Constraint\nEnsures that all values in a column are different.\nExample (during table creation):\nAdd UNIQUE  using ALTER TABLE :\n2. NOT NULL  Constraint\nEnsures that a column cannot contain NULL values.\nCREATE TABLE users (\nid INT PRIMARY KEY,\n    email VARCHAR(100) UNIQUE\n);\nALTER TABLE users\nADD CONSTRAINT unique_email UNIQUE (email);'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 21}, page_content="Example:\nChange an existing column to NOT NULL:\nMake a column nullable again:\n3. CHECK  Constraint\nEnsures that values in a column satisfy a specific condition.\nExample: Allow only dates of birth after Jan 1, 2000\nNaming the constraint ( chk_dob ) helps if you want to drop it later.\n4. DEFAULT  Constraint\nSets a default value for a column if none is provided during insert.\nCREATE TABLE users (\nid INT PRIMARY KEY,\n    name VARCHAR(100) NOT NULL\n);\nALTER TABLE users\nMODIFY COLUMN name VARCHAR(100) NOT NULL;\nALTER TABLE users\nMODIFY COLUMN name VARCHAR(100) NULL;\nALTER TABLE users\nADD CONSTRAINT chk_dob CHECK (date_of_birth > '2000-01-01');"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 22}, page_content='Example:\nAdd DEFAULT using ALTER TABLE :\n5. PRIMARY KEY  Constraint\nUniquely identifies each row. Must be NOT NULL and UNIQUE.\nExample:\nAdd later with ALTER TABLE :\n6. AUTO_INCREMENT\nUsed with PRIMARY KEY  to automatically assign the next number.\nCREATE TABLE users (\nid INT PRIMARY KEY,\n    is_active BOOLEAN DEFAULT TRUE\n);\nALTER TABLE users\nALTER COLUMN is_active SET DEFAULT TRUE;\nCREATE TABLE users (\nid INT PRIMARY KEY,\n    name VARCHAR(100)\n);\nALTER TABLE users\nADD PRIMARY KEY (id);'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 23}, page_content='Example:\nEach new row gets the next available integer value in id .\nSummary Table\nConstraint\nPurpose\nUNIQUE\nPrevents duplicate values\nNOT NULL\nEnsures value is not NULL\nCHECK\nRestricts values using a condition\nDEFAULT\nSets a default value\nPRIMARY KEY\nUniquely identifies each row\nAUTO_INCREMENT\nAutomatically generates unique numbers\nCREATE TABLE users (\nid INT AUTO_INCREMENT PRIMARY KEY,\n    name VARCHAR(100)\n);'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 24}, page_content="SQL Functions (MySQL)\nSQL functions help you analyze, transform, or summarize data in your tables.\nWe’ll use the users  table which includes:\nid , name , email , gender , date_of_birth , salary , created_at\n1. Aggregate Functions\nThese return a single value from a set of rows.\nCOUNT()\nCount total number of users:\nCount users who are Female:\nMIN()  and MAX()\nGet the minimum and maximum salary:\n• \nSELECT COUNT(*) FROM users;\nSELECT COUNT(*) FROM users WHERE gender = 'Female';\nSELECT MIN(salary) AS min_salary, MAX(salary) AS max_salary FROM users;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 25}, page_content='SUM()\nCalculate total salary payout:\nAVG()\nFind average salary:\nGrouping with GROUP BY\nAverage salary by gender:\n2. String Functions\nLENGTH()\nLength of user names:\nSELECT SUM(salary) AS total_payroll FROM users;\nSELECT AVG(salary) AS avg_salary FROM users;\nSELECT gender, AVG(salary) AS avg_salary\nFROM users\nGROUP BY gender;\nSELECT name, LENGTH(name) AS name_length FROM users;'),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 26}, page_content="LOWER()  and UPPER()\nConvert names to lowercase or uppercase:\nCONCAT()\nCombine name and email:\n3. Date Functions\nNOW()\nCurrent date and time:\nYEAR() , MONTH() , DAY()\nExtract parts of date_of_birth :\nSELECT name, LOWER(name) AS lowercase_name FROM users;\nSELECT name, UPPER(name) AS uppercase_name FROM users;\nSELECT CONCAT(name, ' <', email, '>') AS user_contact FROM users;\nSELECT NOW();\nSELECT name, YEAR(date_of_birth) AS birth_year FROM users;"),
#  Document(metadata={'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': '2025-07-13T11:32:27+00:00', 'source': '..\\data\\pdf\\MySQL Handbook.pdf', 'file_path': '..\\data\\pdf\\MySQL Handbook.pdf', 'total_pages': 72, 'format': 'PDF 1.7', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-07-13T11:32:27+00:00', 'trapped': '', 'modDate': 'D:20250713113227Z', 'creationDate': 'D:20250713113227Z', 'page': 27}, page_content='DATEDIFF()\nFind number of days between today and birthdate:\nTIMESTAMPDIFF()\nCalculate age in years:\n4. Mathematical Functions\nROUND() , FLOOR() , CEIL()\nMOD()\nFind even or odd user IDs:\nSELECT name, DATEDIFF(CURDATE(), date_of_birth) AS days_lived FROM users;\nSELECT name, TIMESTAMPDIFF(YEAR, date_of_birth, CURDATE()) AS age FROM users;\nSELECT salary,\n       ROUND(salary) AS rounded,\n       FLOOR(salary) AS floored,\n       CEIL(salary) AS ceiled\nFROM users;\nSELECT id, MOD(id, 2) AS remainder FROM users;'),
# ...
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 21}, page_content="SQL for Data Analytics\nPage 22\nSQL for Data Analytics · Complete Reference Guide\nFROM activity\nGROUP BY cohort_month, period\nORDER BY cohort_month, period;\nClassic cohort retention table\n10.3 Funnel Analysis\n-- Conversion funnel: Visit → SignUp → Purchase → Repeat\nWITH funnel AS (\n    SELECT\n        user_id,\n        MAX(CASE WHEN event='page_visit'   THEN 1 ELSE 0 END) AS visited,\n        MAX(CASE WHEN event='signup'       THEN 1 ELSE 0 END) AS signed_up,\n        MAX(CASE WHEN event='purchase'     THEN 1 ELSE 0 END) AS purchased,\n        MAX(CASE WHEN event='2nd_purchase' THEN 1 ELSE 0 END) AS repeated\n    FROM events\n    GROUP BY user_id\n)\nSELECT\n    SUM(visited)   AS step1_visitors,\n    SUM(signed_up) AS step2_signups,\n    SUM(purchased) AS step3_purchases,\n    SUM(repeated)  AS step4_repeats,\n    ROUND(100.0*SUM(signed_up) /NULLIF(SUM(visited)  ,0),1) AS visit_to_signup_pct,\n    ROUND(100.0*SUM(purchased) /NULLIF(SUM(signed_up),0),1) AS signup_to_purchase_pct,\n    ROUND(100.0*SUM(repeated)  /NULLIF(SUM(purchased),0),1) AS repeat_rate_pct\nFROM funnel;\n10.4 Percentile & Distribution Analysis\n-- Percentiles (PostgreSQL, BigQuery)\nSELECT\n    PERCENTILE_CONT(0.25) WITHIN GROUP (ORDER BY salary) AS p25,\n    PERCENTILE_CONT(0.50) WITHIN GROUP (ORDER BY salary) AS median,\n    PERCENTILE_CONT(0.75) WITHIN GROUP (ORDER BY salary) AS p75,\n    PERCENTILE_CONT(0.90) WITHIN GROUP (ORDER BY salary) AS p90,\n    PERCENTILE_CONT(0.95) WITHIN GROUP (ORDER BY salary) AS p95\nFROM employees;\n-- Using window function (works in more dialects)\nSELECT\n    salary,\n    NTILE(4)  OVER (ORDER BY salary) AS quartile,\n    NTILE(10) OVER (ORDER BY salary) AS decile,\n    NTILE(100)OVER (ORDER BY salary) AS percentile\nFROM employees;\n-- SQL Server approximation\nSELECT\n    DISTINCT PERCENTILE_CONT(0.5) WITHIN GROUP (ORDER BY salary)\n             OVER (PARTITION BY department_id) AS dept_median_salary\nFROM employees;\n10.5 Sessionisation (Gap & Island)"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 22}, page_content='SQL for Data Analytics\nPage 23\nSQL for Data Analytics · Complete Reference Guide\n-- Assign session IDs: new session if gap > 30 min\nWITH gaps AS (\n    SELECT user_id, event_time,\n           LAG(event_time) OVER (PARTITION BY user_id ORDER BY event_time) AS prev_time,\n           CASE WHEN DATEDIFF(minute,\n                     LAG(event_time) OVER (PARTITION BY user_id ORDER BY event_time),\n                     event_time) > 30\n                     OR LAG(event_time) OVER (PARTITION BY user_id ORDER BY event_time) IS NULL\n                THEN 1 ELSE 0 END AS is_new_session\n    FROM events\n),\nsessions AS (\n    SELECT *,\n           SUM(is_new_session) OVER (PARTITION BY user_id ORDER BY event_time) AS session_id\n    FROM gaps\n)\nSELECT user_id, session_id, MIN(event_time) AS session_start,\n       MAX(event_time) AS session_end,\n       COUNT(*) AS events_in_session,\n       DATEDIFF(minute, MIN(event_time), MAX(event_time)) AS duration_min\nFROM sessions\nGROUP BY user_id, session_id;'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 23}, page_content="SQL for Data Analytics\nPage 24\nSQL for Data Analytics · Complete Reference Guide\n11. Data Cleaning in SQL\nNULL handling, deduplication, type casting, standardisation, outlier detection\n11.1 Detecting Data Quality Issues\n-- Null audit across all columns\nSELECT\n    COUNT(*)                                AS total_rows,\n    COUNT(*) - COUNT(customer_id)           AS null_customer_id,\n    COUNT(*) - COUNT(email)                 AS null_email,\n    COUNT(*) - COUNT(phone)                 AS null_phone,\n    COUNT(*) - COUNT(signup_date)           AS null_signup_date,\n    ROUND(100.0*(COUNT(*)-COUNT(email))/COUNT(*),1) AS pct_missing_email\nFROM customers;\n-- Duplicate detection\nSELECT email, COUNT(*) AS occurrences\nFROM customers\nGROUP BY email\nHAVING COUNT(*) > 1\nORDER BY occurrences DESC;\n11.2 Deduplication\n-- Keep only the most recent record per customer (CTE + ROW_NUMBER)\nWITH ranked AS (\n    SELECT *,\n           ROW_NUMBER() OVER (PARTITION BY customer_id\n                              ORDER BY updated_at DESC) AS rn\n    FROM customers\n)\nSELECT * FROM ranked WHERE rn = 1;\n-- Delete duplicates keeping lowest ID (SQL Server / PostgreSQL)\nDELETE FROM customers\nWHERE customer_id NOT IN (\n    SELECT MIN(customer_id)\n    FROM customers\n    GROUP BY email\n);\n11.3 Type Casting & Conversion\n-- CAST (ANSI standard)\nSELECT CAST('2024-01-15' AS DATE)       AS date_val,\n       CAST('3.14'       AS DECIMAL(5,2)) AS num_val,\n       CAST(salary       AS VARCHAR(20))  AS salary_str;\n-- TRY_CAST / TRY_CONVERT (SQL Server) – returns NULL instead of error\nSELECT TRY_CAST(messy_col AS INT) AS safe_int FROM raw_data;\n-- PostgreSQL casting shorthand\nSELECT '3.14'::DECIMAL(5,2), order_date::VARCHAR;"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 24}, page_content="SQL for Data Analytics\nPage 25\nSQL for Data Analytics · Complete Reference Guide\n-- Safe numeric conversion check\nSELECT col,\n       CASE WHEN col NOT LIKE '%[^0-9]%' AND col != ''\n            THEN CAST(col AS INT) ELSE NULL END AS safe_int\nFROM raw_data;\n11.4 Standardising & Cleaning Values\n-- Standardise free-text fields\nSELECT\n    customer_id,\n    TRIM(UPPER(REPLACE(REPLACE(gender,'male','M'),'female','F'))) AS gender_clean,\n    CASE\n        WHEN LOWER(country) IN ('us','usa','united states','america') THEN 'United States'\n        WHEN LOWER(country) IN ('uk','gb','united kingdom','britain') THEN 'United Kingdom'\n        ELSE TRIM(INITCAP(country))    -- PostgreSQL: capitalize first letter\n    END AS country_clean,\n    REGEXP_REPLACE(phone,'[^0-9]','') AS phone_digits   -- digits only\nFROM customers;\n-- Flag outliers (IQR method)\nWITH stats AS (\n    SELECT\n        PERCENTILE_CONT(0.25) WITHIN GROUP (ORDER BY salary) AS q1,\n        PERCENTILE_CONT(0.75) WITHIN GROUP (ORDER BY salary) AS q3\n    FROM employees\n)\nSELECT e.*, s.q1, s.q3,\n       CASE WHEN salary < s.q1 - 1.5*(s.q3-s.q1)\n              OR salary > s.q3 + 1.5*(s.q3-s.q1)\n            THEN 'Outlier' ELSE 'Normal' END AS outlier_flag\nFROM employees e CROSS JOIN stats s;"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 25}, page_content="SQL for Data Analytics\nPage 26\nSQL for Data Analytics · Complete Reference Guide\n12. Performance & Best Practices\nIndexing, query optimisation, anti-patterns, UNION, EXPLAIN, tips\n12.1 UNION & UNION ALL\n-- UNION removes duplicates (slower)\nSELECT customer_id FROM current_customers\nUNION\nSELECT customer_id FROM archived_customers;\n-- UNION ALL keeps duplicates (faster – use when you know data is distinct)\nSELECT 'current' AS source, customer_id, name FROM current_customers\nUNION ALL\nSELECT 'archived',           customer_id, name FROM archived_customers;\n-- Stack multiple result sets\nSELECT 'Q1' AS quarter, SUM(revenue) FROM sales WHERE quarter=1\nUNION ALL\nSELECT 'Q2',             SUM(revenue) FROM sales WHERE quarter=2\nUNION ALL\nSELECT 'Q3',             SUM(revenue) FROM sales WHERE quarter=3\nUNION ALL\nSELECT 'Q4',             SUM(revenue) FROM sales WHERE quarter=4;\n12.2 INTERSECT & EXCEPT (MINUS)\n-- Customers who exist in BOTH tables\nSELECT customer_id FROM online_orders\nINTERSECT\nSELECT customer_id FROM store_orders;\n-- Customers in online but NOT in store (EXCEPT = MINUS in Oracle)\nSELECT customer_id FROM online_orders\nEXCEPT          -- use MINUS in Oracle\nSELECT customer_id FROM store_orders;\n12.3 Performance Anti-Patterns to Avoid\nAnti-Pattern\nProblem\nBetter Approach\nSELECT *\nPulls all columns; breaks cached plans\nList only needed columns\nFunction on indexed col in WHEREDisables index seek\nRewrite: col BETWEEN x AND y\nCorrelated subquery in SELECT Runs once per row\nUse JOIN or window function\nNOT IN with NULLs\nReturns 0 rows if list has NULL\nUse NOT EXISTS instead\nImplicit type conversion\nIndex not used\nCAST explicitly or match types\nOR on different columns\nCan't use composite index\nUse UNION ALL instead\nDISTINCT as a fix\nMasks JOIN problems\nFind and fix root join issue"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 26}, page_content="SQL for Data Analytics\nPage 27\nSQL for Data Analytics · Complete Reference Guide\nORDER BY in subquery\nNo guarantee + wastes resources\nSort in outermost query only\nWildcard LIKE '%term%'\nFull table scan (no index)\nUse full-text search instead\n12.4 EXPLAIN / Query Plan\n-- PostgreSQL / MySQL\nEXPLAIN SELECT * FROM orders WHERE customer_id = 1001;\nEXPLAIN ANALYZE SELECT * FROM orders WHERE customer_id = 1001;  -- actually runs it\n-- SQL Server\nSET STATISTICS IO ON;\nSET STATISTICS TIME ON;\nSELECT * FROM orders WHERE customer_id = 1001;\n-- Look for: Table Scan (bad) vs Index Seek/Scan (good)\n-- High cost operations: Hash Match, Sort, Nested Loops on large tables\n12.5 Useful Analytical SQL Cheatsheet\nPattern\nSQL Technique\nUse Case\nTop N per group\nROW_NUMBER + filter\nAnalytics, rankings\nRunning total\nSUM OVER (ORDER BY)\nFinance, inventory\nMoving average\nAVG OVER (ROWS 6 PRECEDING)\nTime series smoothing\nPeriod-over-period\nLAG(col, 12) OVER\nMoM, YoY reports\nDe-duplicate\nROW_NUMBER PARTITION BY key\nData cleaning\nFill NULLs (forward fill)\nLAST_VALUE IGNORE NULLS\nTime series gaps\nFind gaps\nLAG/LEAD + DATEDIFF\nSession analysis\nPivot rows to columns\nConditional SUM(CASE)\nReporting\nUnpivot columns to rows\nUNION ALL or UNPIVOT\nNormalisation\nHierarchical traverse\nRecursive CTE\nOrg charts, BOM\nMedian\nPERCENTILE_CONT(0.5)\nStatistics\nCohort retention\nDATEDIFF to cohort month\nUser analytics\n12.6 SQL Dialect Quick Reference\nFeature\nMySQL / BigQuery\nSQL Server\nOracle\nLimit rows\nLIMIT n\nTOP n / FETCH FIRST n\nROWNUM / FETCH FIRST\nString concat\nCONCAT() or ||\n+ operator\n|| or CONCAT()\nCurrent date\nCURRENT_DATE / NOW()\nGETDATE()\nSYSDATE\nIf null\nIFNULL / COALESCE\nISNULL / COALESCE\nNVL / COALESCE"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T06:38:07+00:00', 'source': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'file_path': '..\\data\\pdf\\SQL_for_Data_Analytics.pdf', 'total_pages': 28, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-05-11T06:38:07+00:00', 'trapped': '', 'modDate': "D:20260511063807+00'00'", 'creationDate': "D:20260511063807+00'00'", 'page': 27}, page_content='SQL for Data Analytics\nPage 28\nSQL for Data Analytics · Complete Reference Guide\nAuto-increment\nAUTO_INCREMENT\nIDENTITY(1,1)\nSEQUENCE / GENERATED\nRegex match\nREGEXP / RLIKE\nLIKE (basic only)\nREGEXP_LIKE\nDate diff\nDATEDIFF(unit,d1,d2)\nDATEDIFF(d1,d2)\nMONTHS_BETWEEN\nPivot\nManual CASE SUM\nPIVOT operator\nManual CASE SUM\nRecursive CTE\nWITH RECURSIVE\nWITH (no keyword)\nWITH (no keyword)\nTip: Write readable SQL: use consistent capitalisation for keywords, one clause per line, meaningful aliases, and CTEs to\nbreak up complex logic. Future-you (and your teammates) will thank you.')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
